# %% [markdown]
# <a href="https://colab.research.google.com/github/celeneheng/IS170_Binder/blob/1-Feature-Engineeering/HW2YadiraValenzuela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import io
import pandas as pd

# %%
from google.colab import files
df = files.upload()
# Out:
#      <input type="file" id="files-38ab9330-462a-46e4-847d-1da5fd1edb7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38ab9330-462a-46e4-847d-1da5fd1edb7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Lending_Equity1.csv')
print(df)
# Out:
#     Reporting Year       Action Taken  Total Units     Loan Purpose  \
# 0             2022   6-Purchased loan            1     31-Refinance
# 1             2022  1-Loan originated            1     31-Refinance
# 2             2022   6-Purchased loan            1      32-Cash Out
# 3             2022  1-Loan originated            1     31-Refinance
# 4             2022   6-Purchased loan            1     31-Refinance
# ..             ...                ...          ...              ...
# 94            2022  1-Loan originated            1      32-Cash Out
# 95            2022  1-Loan originated            1      32-Cash Out
# 96            2022   6-Purchased loan            1     31-Refinance
# 97            2022  1-Loan originated            1  1-Home Purchase
# 98            2022   6-Purchased loan            1  1-Home Purchase
#
#     Interest Rate  Loan Term (Months)  Loan Amount  Property Value  \
# 0            0.03                 360     286500.0          328000
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.dtypes)
# Out:
# Reporting Year                 int64
# Action Taken                  object
# Total Units                    int64
# Loan Purpose                  object
# Interest Rate                float64
# Loan Term (Months)             int64
# Loan Amount                  float64
# Property Value                 int64
# Combined-Loan-value Ratio    float64
# dtype: object

# %% [markdown]
# identifying null or missing values

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Reporting Year             99 non-null     int64
#  1   Action Taken               99 non-null     object
#  2   Total Units                99 non-null     int64
#  3   Loan Purpose               99 non-null     object
#  4   Interest Rate              98 non-null     float64
#  5   Loan Term (Months)         99 non-null     int64
#  6   Loan Amount                99 non-null     float64
#  7   Property Value             99 non-null     int64
#  8   Combined-Loan-value Ratio  99 non-null     float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 7.1+ KB
# None

# %%
df1 = df.dropna()

# %% [markdown]
# replacing the 0 values with the mean for the combine loan value ratio

# %%
df['Combined-Loan-value Ratio']=df['Combined-Loan-value Ratio'].replace(0,df['Combined-Loan-value Ratio'].mean())
df
# Out:
#     Reporting Year       Action Taken  Total Units     Loan Purpose  \
# 0             2022   6-Purchased loan            1     31-Refinance
# 1             2022  1-Loan originated            1     31-Refinance
# 2             2022   6-Purchased loan            1      32-Cash Out
# 3             2022  1-Loan originated            1     31-Refinance
# 4             2022   6-Purchased loan            1     31-Refinance
# ..             ...                ...          ...              ...
# 94            2022  1-Loan originated            1      32-Cash Out
# 95            2022  1-Loan originated            1      32-Cash Out
# 96            2022   6-Purchased loan            1     31-Refinance
# 97            2022  1-Loan originated            1  1-Home Purchase
# 98            2022   6-Purchased loan            1  1-Home Purchase
#
#     Interest Rate  Loan Term (Months)  Loan Amount  Property Value  \
# 0            0.03                 360     286500.0          328000
# ...

# %% [markdown]
# string to interger conversion

# %%
#importing labelEncoder from Sklearn
from sklearn.preprocessing import LabelEncoder

# %%
#creating an instance of label encoder
le = LabelEncoder()

label = le.fit_transform(df['Action Taken'])

#printing label
label
# Out:
# array([2, 0, 2, 0, 2, 0, 2, 0, 0, 0, 0, 2, 0, 0, 0, 0, 0, 2, 2, 0, 2, 0,
#        2, 2, 0, 0, 0, 0, 0, 0, 0, 0, 0, 2, 1, 0, 0, 2, 2, 0, 0, 2, 0, 0,
#        0, 0, 0, 0, 2, 0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 0, 0, 2, 0, 2, 2, 0,
#        0, 0, 2, 0, 2, 2, 0, 0, 2, 0, 0, 2, 2, 2, 0, 2, 0, 0, 0, 0, 0, 0,
#        0, 2, 0, 0, 0, 0, 0, 0, 2, 0, 2])

# %%
df.drop('Action Taken', axis=1, inplace=True)

# %%
df['Action Taken'] = label
df
# Out:
#     Reporting Year  Total Units     Loan Purpose  Interest Rate  \
# 0             2022            1     31-Refinance           0.03
# 1             2022            1     31-Refinance           0.03
# 2             2022            1      32-Cash Out           0.03
# 3             2022            1     31-Refinance           0.03
# 4             2022            1     31-Refinance           0.03
# ..             ...          ...              ...            ...
# 94            2022            1      32-Cash Out           0.04
# 95            2022            1      32-Cash Out           0.03
# 96            2022            1     31-Refinance           0.03
# 97            2022            1  1-Home Purchase           0.03
# 98            2022            1  1-Home Purchase           0.03
#
#     Loan Term (Months)  Loan Amount  Property Value  \
# 0                  360     286500.0          328000
# 1                  360     438000.0          495000
# ...

# %% [markdown]
# Normalizing data

# %%
from sklearn import preprocessing
import pandas as pd

# %%
df_scaled=preprocessing.scale(df)

# %%
df_scaled['Loan Amount']=df['Property Value']
df=df_scaled
# Out:
#   File "<ipython-input-127-d25946fe260a>", line 1
#     df_scaled[//'Loan Amount']=df[//'Property Value']
#               ^
# SyntaxError: invalid syntax

# %%
old_cols=df.columns.values
new_cols=['Total Units','Loan Term (Months)','Property Value']
df=df.reindex(columns=new_cols)
df
# Out:
#     Total Units  Loan Term (Months)  Property Value
# 0             1                 360          328000
# 1             1                 360          495000
# 2             1                 360          430000
# 3             1                 240          365000
# 4             1                 240          380000
# ..          ...                 ...             ...
# 94            1                 360          745000
# 95            1                 240          550000
# 96            1                 180          485000
# 97            1                 360          275000
# 98            1                 360          354900
#
# [99 rows x 3 columns]

# %%
print(df.rename(columns={'Total Units':'Buildings','Loan Term (Months)':'Loan Duration','Property Value':'Housing Prices'}))
# Out:
#     Buildings  Loan Duration  Housing Prices
# 0           1            360          328000
# 1           1            360          495000
# 2           1            360          430000
# 3           1            240          365000
# 4           1            240          380000
# ..        ...            ...             ...
# 94          1            360          745000
# 95          1            240          550000
# 96          1            180          485000
# 97          1            360          275000
# 98          1            360          354900
#
# [99 rows x 3 columns]
